# %%
import pandas as pd
import os

BASE = "/content"

file_paths = {
    "TCN_Lagged": "TCN_model_search_lagged_18-03-2025-21-59-40.csv",
    "TCN_Search": "TCN_new_model_search_26-11-2024-00-27-43.csv",
    "TCN_New": "TCN_new_model_26-11-2024-00-40-59.csv"
}

dataframes = {
    name: pd.read_csv(os.path.join(BASE, file))
    for name, file in file_paths.items()
}

import matplotlib.pyplot as plt
import seaborn as sns

# Rename keys for readability
model_names = {
    "TCN_Lagged": "TCN Search Lagged", # Corrected key
    "TCN_New": "TCN New Model",     # Corrected key
    "TCN_Search": "TCN Search",     # Corrected key
}

# Prepare data for visualization
metric_cols = ["NRMSE All Validation", "MAE (DengRate_all) Val"]
merged_data = []

for model, df in dataframes.items():
    for metric in metric_cols:
        for _, row in df.iterrows():
            merged_data.append({
                "Model": model_names[model],
                "State": row["Department"],
                "Metric": metric,
                "Value": row[metric],
            })

# Convert to DataFrame
df_plot = pd.DataFrame(merged_data)

# Overall Comparison: Boxplots of Metrics Across Models
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_plot, x="Metric", y="Value", hue="Model")
plt.yscale("log")  # Log scale for better visibility
plt.title("Overall Model Comparison (NRMSE & MAE)")
plt.xticks(rotation=30)
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()
# Re-prepare the data for visualization
merged_data = []
for model, df in dataframes.items():
    for metric in metric_cols:
        for _, row in df.iterrows():
            merged_data.append({
                "Model": model_names[model],
                "State": row["Department"],
                "Metric": metric,
                "Value": row[metric],
            })

# Convert to DataFrame
df_plot = pd.DataFrame(merged_data)

# Single visualization for all states
plt.figure(figsize=(15, 7))
sns.barplot(data=df_plot, x="State", y="Value", hue="Model", ci=None)
plt.yscale("log")  # Log scale for better visibility
plt.xticks(rotation=90)
plt.title("State-wise Model Comparison (NRMSE & MAE)")
plt.xlabel("State")
plt.ylabel("Metric Value (Log Scale)")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend(title="Model")
plt.show()

import seaborn as sns
import matplotlib.pyplot as plt

# FacetGrid for small multiples
g = sns.FacetGrid(df_plot, col="Metric", hue="Model", sharey=False, height=5, aspect=1.5)
g.map(sns.barplot, "State", "Value", order=sorted(df_plot["State"].unique()), ci=None)
g.set_xticklabels(rotation=90)
g.set_ylabels("Value (Log Scale)")
g.set_titles(col_template="{col_name}")
g.add_legend()

plt.suptitle("Facet Grid of Metrics Across Models and States", y=1.05, fontsize=14)
plt.show()
import pandas as pd
import numpy as np
import math
import os
import matplotlib.pyplot as plt # Added this import

# Reload the datasets
BASE = "/content" # Define BASE as it's used here
file_paths = {
    "model_1": os.path.join(BASE, "TCN_model_search_lagged_18-03-2025-21-59-40.csv"), # Corrected path and filename
    "model_2": os.path.join(BASE, "TCN_new_model_26-11-2024-00-40-59.csv"),
    "model_3": os.path.join(BASE, "TCN_new_model_search_26-11-2024-00-27-43.csv"),
    "actual_data": os.path.join(BASE, "merged_dataset.csv") # Corrected path based on available files
}

def plot_taylor_diagram(std_devs, correlations, ref_std, labels, colors):
    """ Generate a Taylor Diagram manually using Matplotlib """
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, polar=True)

    # Convert correlation to angles (arccosine of correlation)
    angles = np.arccos(correlations)

    # Reference circle (actual standard deviation)
    theta = np.linspace(0, np.pi / 2, 100)
    ax.plot(theta, [ref_std] * 100, "k--", label="Reference")

    # Plot each model's performance
    for i, label in enumerate(labels):
        ax.plot(angles[i], std_devs[i], "o", label=label, color=colors[i], markersize=8)

    # Configure polar plot
    ax.set_xticks(np.arccos([1, 0.9, 0.8, 0.7, 0.6]))  # Correlation markers
    ax.set_xticklabels(["1", "0.9", "0.8", "0.7", "0.6"])
    ax.set_ylim(0, max(std_devs) + 0.05)
    ax.set_yticks(np.linspace(0, max(std_devs), 5))

    # Labels and title
    plt.legend(loc="upper right")
    plt.title("Taylor Diagram for Model Comparison")
    plt.show()

# Load data into a dictionary
datasets = {} # Initialize datasets to avoid NameError if file loading fails
try:
    for key, path in file_paths.items():
        datasets[key] = pd.read_csv(path)
except FileNotFoundError as e:
    print(f"Skipping Taylor Diagram due to missing file: {e}. 'actual_data' is required but not found.")
    # Removed exit() to allow the program to continue and handle the missing file gracefully

# Mapping department IDs to names
DEP_NAMES = {
    11: 'Rondônia', 12: 'Acre', 13: 'Amazonas', 14: 'Roraima', 15: 'Pará', 16: 'Amapá', 17: 'Tocantins',
    21: 'Maranhão', 22: 'Piauí', 23: 'Ceará', 24: 'Rio Grande do Norte', 25: 'Paraíba', 26: 'Pernambuco',
    27: 'Alagoas', 28: 'Sergipe', 29: 'Bahia', 31: 'Minas Gerais', 32: 'Espírito Santo', 33: 'Rio de Janeiro',
    35: 'São Paulo', 41: 'Paraná', 42: 'Santa Catarina', 43: 'Rio Grande do Sul', 50: 'Mato Grosso do Sul',
    51: 'Mato Grosso', 52: 'Goiás', 53: 'Distrito Federal'
}

# Map department IDs to names
# Only proceed if 'actual_data' was successfully loaded
if "actual_data" in datasets:
    actual_data = datasets["actual_data"].copy()
    actual_data["Department"] = actual_data["dep_id"].map(DEP_NAMES)

    # Compute average dengue rates per department
    actual_avg = actual_data.groupby("Department")[["DengRate_all", "DengRate_019"]].mean().reset_index()

    # Merge actual averages with model metric datasets
    merged_datasets = {}
    for model_name, model_df in datasets.items():
        if model_name != "actual_data":
            merged_datasets[model_name] = model_df.merge(actual_avg, on="Department", how="left")

    # Compute statistics for Taylor diagram
    model_stats = {}
    for model_name, df in merged_datasets.items():
        std_dev = df["NRMSE All Validation"].replace([np.inf, -np.inf], np.nan).dropna().std()
        correlation = np.corrcoef(df["NRMSE All Validation"].replace([np.inf, -np.inf], np.nan).dropna(),
                                  df["DengRate_all"].dropna())[0, 1]
        model_stats[model_name] = {"std_dev": std_dev, "correlation": correlation}

    # Convert to arrays for plotting
    labels = list(model_stats.keys())
    std_devs = np.array([model_stats[m]["std_dev"] for m in labels])
    correlations = np.array([model_stats[m]["correlation"] for m in labels])
    ref_std = actual_avg["DengRate_all"].std()  # Reference standard deviation

    # Plot Taylor diagram
    plot_taylor_diagram(std_devs, correlations, ref_std, labels, ["r", "g", "b"])
else:
    print("Taylor Diagram cannot be plotted because 'actual_data' file is missing.")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Define BASE path for files
BASE = "/content"

# Define file paths for TCN models
file_paths = {
    "TCN_Lagged": "TCN_model_search_lagged_18-03-2025-21-59-40.csv",
    "TCN_Search": "TCN_new_model_search_26-11-2024-00-27-43.csv",
    "TCN_New": "TCN_new_model_26-11-2024-00-40-59.csv"
}

# Load the CSV files into dataframes
dataframes = {
    name: pd.read_csv(os.path.join(BASE, file))
    for name, file in file_paths.items()
}

# Rename keys for readability (TCN models)
model_names = {
    "TCN_Lagged": "TCN Search Lagged",
    "TCN_New": "TCN New Model",
    "TCN_Search": "TCN Search",
}

# Prepare data for visualization
metric_cols = ["NRMSE All Validation", "MAE (DengRate_all) Val"]
merged_data = []

for model, df in dataframes.items():
    for metric in metric_cols:
        for _, row in df.iterrows():
            merged_data.append({
                "Model": model_names[model],
                "State": row["Department"],
                "Metric": metric,
                "Value": row[metric],
            })

# Convert to DataFrame
df_plot = pd.DataFrame(merged_data)

# Overall Comparison: Boxplots of Metrics Across Models
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_plot, x="Metric", y="Value", hue="Model")
plt.yscale("log")  # Log scale for better visibility
plt.title("Overall Model Comparison (NRMSE & MAE)")
plt.xticks(rotation=30)
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()

# Re-prepare the data for visualization (this part is redundant if df_plot is already created correctly above, but kept for consistency with original cell structure)
merged_data = []
for model, df in dataframes.items():
    for metric in metric_cols:
        for _, row in df.iterrows():
            merged_data.append({
                "Model": model_names[model],
                "State": row["Department"],
                "Metric": metric,
                "Value": row[metric],
            })

# Convert to DataFrame
df_plot = pd.DataFrame(merged_data)

# Single visualization for all states
plt.figure(figsize=(15, 7))
sns.barplot(data=df_plot, x="State", y="Value", hue="Model", errorbar=None) # Changed ci to errorbar
plt.yscale("log")  # Log scale for better visibility
plt.xticks(rotation=90)
plt.title("State-wise Model Comparison (NRMSE & MAE)")
plt.xlabel("State")
plt.ylabel("Metric Value (Log Scale)")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend(title="Model")
plt.show()

# FacetGrid for small multiples
g = sns.FacetGrid(df_plot, col="Metric", hue="Model", sharey=False, height=5, aspect=1.5)
g.map(sns.barplot, "State", "Value", order=sorted(df_plot["State"].unique()), errorbar=None) # Changed ci to errorbar
g.set_xticklabels(rotation=90)
g.set_ylabels("Value (Log Scale)")
g.set_titles(col_template="{col_name}")
g.add_legend()

plt.suptitle("Facet Grid of Metrics Across Models and States", y=1.05, fontsize=14)
plt.show()

import math
import pandas as pd # Added this import
import numpy as np # Added this import
import os # Added this import
import matplotlib.pyplot as plt # Added this import

# Reload the datasets
BASE = "/content" # Define BASE path for files
file_paths = {
    "model_1": os.path.join(BASE, "TCN_model_search_lagged_18-03-2025-21-59-40.csv"), # Corrected path to use available TCN model
    "model_2": os.path.join(BASE, "TCN_new_model_26-11-2024-00-40-59.csv"), # Corrected path to use available TCN model
    "model_3": os.path.join(BASE, "TCN_new_model_search_26-11-2024-00-27-43.csv"), # Corrected path to use available TCN model
    "actual_data": os.path.join(BASE, "merged_dataset.csv")
}

def plot_taylor_diagram(std_devs, correlations, ref_std, labels, colors):
    """ Generate a Taylor Diagram manually using Matplotlib """
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, polar=True)

    # Convert correlation to angles (arccosine of correlation)
    angles = np.arccos(correlations)

    # Reference circle (actual standard deviation)
    theta = np.linspace(0, np.pi / 2, 100)
    ax.plot(theta, [ref_std] * 100, "k--", label="Reference")

    # Plot each model's performance
    for i, label in enumerate(labels):
        ax.plot(angles[i], std_devs[i], "o", label=label, color=colors[i], markersize=8)

    # Configure polar plot
    ax.set_xticks(np.arccos([1, 0.9, 0.8, 0.7, 0.6]))  # Correlation markers
    ax.set_xticklabels(["1", "0.9", "0.8", "0.7", "0.6"])
    ax.set_ylim(0, max(std_devs) + 0.05)
    ax.set_yticks(np.linspace(0, max(std_devs), 5))

    # Labels and title
    plt.legend(loc="upper right")
    plt.title("Taylor Diagram for Model Comparison")
    plt.show()

# Load data into a dictionary
datasets = {} # Initialize datasets to avoid NameError if file loading fails
try:
    for key, path in file_paths.items():
        datasets[key] = pd.read_csv(path)
except FileNotFoundError as e:
    print(f"Skipping Taylor Diagram due to missing file: {e}. One or more required files are not found.")
    # Removed exit() to allow the program to continue and handle the missing file gracefully
    # If critical files are missing, subsequent operations might fail or be incomplete.

# Mapping department IDs to names
DEP_NAMES = {
    11: 'Rondônia', 12: 'Acre', 13: 'Amazonas', 14: 'Roraima', 15: 'Pará', 16: 'Amapá', 17: 'Tocantins',
    21: 'Maranhão', 22: 'Piauí', 23: 'Ceará', 24: 'Rio Grande do Norte', 25: 'Paraíba', 26: 'Pernambuco',
    27: 'Alagoas', 28: 'Sergipe', 29: 'Bahia', 31: 'Minas Gerais', 32: 'Espírito Santo', 33: 'Rio de Janeiro',
    35: 'São Paulo', 41: 'Paraná', 42: 'Santa Catarina', 43: 'Rio Grande do Sul', 50: 'Mato Grosso do Sul',
    51: 'Mato Grosso', 52: 'Goiás', 53: 'Distrito Federal'
}

# Map department IDs to names
# Only proceed if 'actual_data' was successfully loaded
if "actual_data" in datasets and len(datasets) > 1: # Ensure actual_data and at least one model are loaded
    actual_data = datasets["actual_data"].copy()
    actual_data["Department"] = actual_data["dep_id"].map(DEP_NAMES)

    # Compute average dengue rates per department
    actual_avg = actual_data.groupby("Department")[["DengRate_all", "DengRate_019"]].mean().reset_index()

    # Merge actual averages with model metric datasets
    merged_datasets = {}
    for model_name, model_df in datasets.items():
        if model_name != "actual_data":
            merged_datasets[model_name] = model_df.merge(actual_avg, on="Department", how="left")

    # Compute statistics for Taylor diagram
    model_stats = {}
    for model_name, df in merged_datasets.items():
        # Handle cases where 'NRMSE All Validation' might have inf values or be empty after dropna
        nrmse_series = df["NRMSE All Validation"].replace([np.inf, -np.inf], np.nan).dropna()
        dengrate_series = df["DengRate_all"].dropna()

        if len(nrmse_series) > 1 and len(dengrate_series) > 1: # Ensure enough data points for std and correlation
            std_dev = nrmse_series.std()
            # Align series for correlation calculation if they have different indices after dropna
            common_index = nrmse_series.index.intersection(dengrate_series.index)
            if len(common_index) > 1:
                correlation = np.corrcoef(nrmse_series.loc[common_index], dengrate_series.loc[common_index])[0, 1]
            else:
                correlation = np.nan # Not enough data for correlation
        else:
            std_dev = np.nan # Not enough data for standard deviation
            correlation = np.nan # Not enough data for correlation

        model_stats[model_name] = {"std_dev": std_dev, "correlation": correlation}

    # Filter out models with NaN stats if any
    valid_model_stats = {name: stats for name, stats in model_stats.items() if not np.isnan(stats["std_dev"]) and not np.isnan(stats["correlation"]) and stats["std_dev"] > 0}

    if valid_model_stats:
        # Convert to arrays for plotting
        labels = list(valid_model_stats.keys())
        std_devs = np.array([valid_model_stats[m]["std_dev"] for m in labels])
        correlations = np.array([valid_model_stats[m]["correlation"] for m in labels])
        ref_std = actual_avg["DengRate_all"].std()  # Reference standard deviation

        # Plot Taylor diagram
        plot_taylor_diagram(std_devs, correlations, ref_std, labels, ["r", "g", "b"][:len(labels)]) # Adjust colors based on number of models
    else:
        print("Not enough valid model data to plot Taylor Diagram.")
else:
    print("Taylor Diagram cannot be plotted because 'actual_data' file is missing or not enough models were loaded.")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os # Added import for os

BASE = "/content" # Defined BASE path

file_paths = {
    "TFT_Model_search_lagged": os.path.join(BASE, "TFT_model_lagged_18-03-2025-22-51-57.csv"),
    "TFT_new_Model": os.path.join(BASE, "TFT_new_model_18-03-2025-23-03-37.csv"),
    "TFT_new_Model_search": os.path.join(BASE, "TFT_model_search_18-03-2025-22-58-39.csv"),
}

# Load the CSV files
dataframes = {name: pd.read_csv(path) for name, path in file_paths.items()}
# Rename keys for readability
model_names = {
    "TFT_Model_search_lagged": "TFT Search Lagged",
    "TFT_new_Model": "TFT New Model",
    "TFT_new_Model_search": "TFT Search",
}

# Prepare data for visualization
metric_cols = ["NRMSE All Validation", "MAE (DengRate_all) Val"]
merged_data = []

for model, df in dataframes.items():
    for metric in metric_cols:
        for _, row in df.iterrows():
            merged_data.append({
                "Model": model_names[model],
                "State": row["Department"],
                "Metric": metric,
                "Value": row[metric],
            })

# Convert to DataFrame
df_plot = pd.DataFrame(merged_data)

# Overall Comparison: Boxplots of Metrics Across Models
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_plot, x="Metric", y="Value", hue="Model")
plt.yscale("log")  # Log scale for better visibility
plt.title("Overall Model Comparison (NRMSE & MAE)")
plt.xticks(rotation=30)
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()

# Re-prepare the data for visualization
merged_data = []
for model, df in dataframes.items():
    for metric in metric_cols:
        for _, row in df.iterrows():
            merged_data.append({
                "Model": model_names[model],
                "State": row["Department"],
                "Metric": metric,
                "Value": row[metric],
            })

# Convert to DataFrame
df_plot = pd.DataFrame(merged_data)

# Single visualization for all states
plt.figure(figsize=(15, 7))
sns.barplot(data=df_plot, x="State", y="Value", hue="Model", errorbar=None) # Changed ci to errorbar
plt.yscale("log")  # Log scale for better visibility
plt.xticks(rotation=90)
plt.title("State-wise Model Comparison (NRMSE & MAE)")
plt.xlabel("State")
plt.ylabel("Metric Value (Log Scale)")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend(title="Model")
plt.show()

# FacetGrid for small multiples
g = sns.FacetGrid(df_plot, col="Metric", hue="Model", sharey=False, height=5, aspect=1.5)
g.map(sns.barplot, "State", "Value", order=sorted(df_plot["State"].unique()), errorbar=None) # Changed ci to errorbar
g.set_xticklabels(rotation=90)
g.set_ylabels("Value (Log Scale)")
g.set_titles(col_template="{col_name}")
g.add_legend()

plt.suptitle("Facet Grid of Metrics Across Models and States", y=1.05, fontsize=14)
plt.show()

import math
import pandas as pd # Added this import
import numpy as np # Added this import
import os # Added this import
import matplotlib.pyplot as plt # Added this import

# Reload the datasets
BASE = "/content" # Define BASE path
file_paths = {
    "model_1": os.path.join(BASE, "TFT_model_lagged_18-03-2025-22-51-57.csv"),
    "model_2": os.path.join(BASE, "TFT_new_model_18-03-2025-23-03-37.csv"),
    "model_3": os.path.join(BASE, "TFT_model_search_18-03-2025-22-58-39.csv"),
    "actual_data": os.path.join(BASE, "merged_dataset.csv")
}

def plot_taylor_diagram(std_devs, correlations, ref_std, labels, colors):
    """ Generate a Taylor Diagram manually using Matplotlib """
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, polar=True)

    # Convert correlation to angles (arccosine of correlation)
    angles = np.arccos(correlations)

    # Reference circle (actual standard deviation)
    theta = np.linspace(0, np.pi / 2, 100)
    ax.plot(theta, [ref_std] * 100, "k--", label="Reference")

    # Plot each model's performance
    for i, label in enumerate(labels):
        ax.plot(angles[i], std_devs[i], "o", label=label, color=colors[i], markersize=8)

    # Configure polar plot
    ax.set_xticks(np.arccos([1, 0.9, 0.8, 0.7, 0.6]))  # Correlation markers
    ax.set_xticklabels(["1", "0.9", "0.8", "0.7", "0.6"])
    ax.set_ylim(0, max(std_devs) + 0.05)
    ax.set_yticks(np.linspace(0, max(std_devs), 5))

    # Labels and title
    plt.legend(loc="upper right")
    plt.title("Taylor Diagram for Model Comparison")
    plt.show()

# Load data into a dictionary
datasets = {} # Initialize datasets to avoid NameError if file loading fails
try:
    for key, path in file_paths.items():
        datasets[key] = pd.read_csv(path)
except FileNotFoundError as e:
    print(f"Skipping Taylor Diagram due to missing file: {e}. One or more required files are not found.")
    # Removed exit() to allow the program to continue and handle the missing file gracefully
    # If critical files are missing, subsequent operations might fail or be incomplete.

# Mapping department IDs to names
DEP_NAMES = {
    11: 'Rondônia', 12: 'Acre', 13: 'Amazonas', 14: 'Roraima', 15: 'Pará', 16: 'Amapá', 17: 'Tocantins',
    21: 'Maranhão', 22: 'Piauí', 23: 'Ceará', 24: 'Rio Grande do Norte', 25: 'Paraíba', 26: 'Pernambuco',
    27: 'Alagoas', 28: 'Sergipe', 29: 'Bahia', 31: 'Minas Gerais', 32: 'Espírito Santo', 33: 'Rio de Janeiro',
    35: 'São Paulo', 41: 'Paraná', 42: 'Santa Catarina', 43: 'Rio Grande do Sul', 50: 'Mato Grosso do Sul',
    51: 'Mato Grosso', 52: 'Goiás', 53: 'Distrito Federal'
}

# Map department IDs to names
# Only proceed if 'actual_data' was successfully loaded
if "actual_data" in datasets and len(datasets) > 1: # Ensure actual_data and at least one model are loaded
    actual_data = datasets["actual_data"].copy()
    actual_data["Department"] = actual_data["dep_id"].map(DEP_NAMES)

    # Compute average dengue rates per department
    actual_avg = actual_data.groupby("Department")[["DengRate_all", "DengRate_019"]].mean().reset_index()

    # Merge actual averages with model metric datasets
    merged_datasets = {}
    for model_name, model_df in datasets.items():
        if model_name != "actual_data":
            merged_datasets[model_name] = model_df.merge(actual_avg, on="Department", how="left")

    # Compute statistics for Taylor diagram
    model_stats = {}
    for model_name, df in merged_datasets.items():
        # Handle cases where 'NRMSE All Validation' might have inf values or be empty after dropna
        nrmse_series = df["NRMSE All Validation"].replace([np.inf, -np.inf], np.nan).dropna()
        dengrate_series = df["DengRate_all"].dropna()

        if len(nrmse_series) > 1 and len(dengrate_series) > 1: # Ensure enough data points for std and correlation
            std_dev = nrmse_series.std()
            # Align series for correlation calculation if they have different indices after dropna
            common_index = nrmse_series.index.intersection(dengrate_series.index)
            if len(common_index) > 1:
                correlation = np.corrcoef(nrmse_series.loc[common_index], dengrate_series.loc[common_index])[0, 1]
            else:
                correlation = np.nan # Not enough data for correlation
        else:
            std_dev = np.nan # Not enough data for standard deviation
            correlation = np.nan # Not enough data for correlation

        model_stats[model_name] = {"std_dev": std_dev, "correlation": correlation}

    # Filter out models with NaN stats if any
    valid_model_stats = {name: stats for name, stats in model_stats.items() if not np.isnan(stats["std_dev"]) and not np.isnan(stats["correlation"]) and stats["std_dev"] > 0}

    if valid_model_stats:
        # Convert to arrays for plotting
        labels = list(valid_model_stats.keys())
        std_devs = np.array([valid_model_stats[m]["std_dev"] for m in labels])
        correlations = np.array([valid_model_stats[m]["correlation"] for m in labels])
        ref_std = actual_avg["DengRate_all"].std()  # Reference standard deviation

        # Plot Taylor diagram
        plot_taylor_diagram(std_devs, correlations, ref_std, labels, ["r", "g", "b"][:len(labels)]) # Adjust colors based on number of models
    else:
        print("Not enough valid model data to plot Taylor Diagram.")
else:
    print("Taylor Diagram cannot be plotted because 'actual_data' file is missing or not enough models were loaded.")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

BASE = "/content"

file_paths = {
    "Catboost_Model_search_lagged": os.path.join(BASE, "catboost_lagged_19-03-2025-00-47-00.csv"),
    "Catboost_new_Model": os.path.join(BASE, "catboost_normal26-11-2024-01-03-19.csv"), # This file is missing
    "Catboost_new_Model_search": os.path.join(BASE, "catboost_search_26-11-2024-02-20-15.csv"), # This file is missing
}

# Load the CSV files, handling missing files gracefully
dataframes = {}
for name, path in file_paths.items():
    try:
        dataframes[name] = pd.read_csv(path)
    except FileNotFoundError:
        print(f"Warning: File not found for {name} at {path}. Skipping this model.")

# Check if any dataframes were loaded
if not dataframes:
    print("Error: No Catboost model dataframes could be loaded. Cannot proceed with visualization.")
else:
    # Rename keys for readability
    model_names = {
        "Catboost_Model_search_lagged": "Catboost Search Lagged",
        "Catboost_new_Model": "Catboost New Model",
        "Catboost_new_Model_search": "Catboost Search",
    }

    # Filter model_names to include only successfully loaded dataframes
    available_model_names = {k: v for k, v in model_names.items() if k in dataframes}

    # Prepare data for visualization
    metric_cols = ["NRMSE All Validation", "MAE (DengRate_all) Val"]
    merged_data = []

    for model, df in dataframes.items():
        for metric in metric_cols:
            for _, row in df.iterrows():
                merged_data.append({
                    "Model": available_model_names[model],
                    "State": row["Department"],
                    "Metric": metric,
                    "Value": row[metric],
                })

    # Convert to DataFrame
    df_plot = pd.DataFrame(merged_data)

    # Overall Comparison: Boxplots of Metrics Across Models
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=df_plot, x="Metric", y="Value", hue="Model")
    plt.yscale("log")  # Log scale for better visibility
    plt.title("Overall Model Comparison (NRMSE & MAE)")
    plt.xticks(rotation=30)
    plt.grid(True, which="both", linestyle="--", linewidth=0.5)
    plt.show()

    # Re-prepare the data for visualization (this part is redundant if df_plot is already created correctly above, but kept for consistency with original cell structure)
    # It's better to reuse df_plot created earlier if dataframes are loaded only once
    # For now, let's keep it to ensure it processes only the available dataframes
    merged_data = []
    for model, df in dataframes.items():
        for metric in metric_cols:
            for _, row in df.iterrows():
                merged_data.append({
                    "Model": available_model_names[model],
                    "State": row["Department"],
                    "Metric": metric,
                    "Value": row[metric],
                })

    # Convert to DataFrame
    df_plot = pd.DataFrame(merged_data)

    # Single visualization for all states
    plt.figure(figsize=(15, 7))
    sns.barplot(data=df_plot, x="State", y="Value", hue="Model", errorbar=None) # Changed ci to errorbar
    plt.yscale("log")  # Log scale for better visibility
    plt.xticks(rotation=90)
    plt.title("State-wise Model Comparison (NRMSE & MAE)")
    plt.xlabel("State")
    plt.ylabel("Metric Value (Log Scale)")
    plt.grid(True, which="both", linestyle="--", linewidth=0.5)
    plt.legend(title="Model")
    plt.show()

    # FacetGrid for small multiples
    g = sns.FacetGrid(df_plot, col="Metric", hue="Model", sharey=False, height=5, aspect=1.5)
    g.map(sns.barplot, "State", "Value", order=sorted(df_plot["State"].unique()), errorbar=None) # Changed ci to errorbar
    g.set_xticklabels(rotation=90)
    g.set_ylabels("Value (Log Scale)")
    g.set_titles(col_template="{col_name}")
    g.add_legend()

    plt.suptitle("Facet Grid of Metrics Across Models and States", y=1.05, fontsize=14)
    plt.show()

import math
import pandas as pd # Added this import
import numpy as np # Added this import
import os # Added this import
import matplotlib.pyplot as plt # Added this import

# Reload the datasets
BASE = "/content" # Define BASE path
file_paths = {
    "model_1": os.path.join(BASE, "catboost_lagged_19-03-2025-00-47-00.csv"),
    "model_2": os.path.join(BASE, "catboost_normal26-11-2024-01-03-19.csv"),
    "model_3": os.path.join(BASE, "catboost_search_26-11-2024-02-20-15.csv"),
    "actual_data": os.path.join(BASE, "merged_dataset.csv")
}

def plot_taylor_diagram(std_devs, correlations, ref_std, labels, colors):
    """ Generate a Taylor Diagram manually using Matplotlib """
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, polar=True)

    # Convert correlation to angles (arccosine of correlation)
    angles = np.arccos(correlations)

    # Reference circle (actual standard deviation)
    theta = np.linspace(0, np.pi / 2, 100)
    ax.plot(theta, [ref_std] * 100, "k--", label="Reference")

    # Plot each model's performance
    for i, label in enumerate(labels):
        ax.plot(angles[i], std_devs[i], "o", label=label, color=colors[i], markersize=8)

    # Configure polar plot
    ax.set_xticks(np.arccos([1, 0.9, 0.8, 0.7, 0.6]))  # Correlation markers
    ax.set_xticklabels(["1", "0.9", "0.8", "0.7", "0.6"])
    ax.set_ylim(0, max(std_devs) + 0.05)
    ax.set_yticks(np.linspace(0, max(std_devs), 5))

    # Labels and title
    plt.legend(loc="upper right")
    plt.title("Taylor Diagram for Model Comparison")
    plt.show()

# Load data into a dictionary
datasets = {} # Initialize datasets
for key, path in file_paths.items():
    try:
        datasets[key] = pd.read_csv(path)
    except FileNotFoundError:
        print(f"Warning: File not found for {key} at {path}. Skipping this model/data.")

# Mapping department IDs to names
DEP_NAMES = {
    11: 'Rondônia', 12: 'Acre', 13: 'Amazonas', 14: 'Roraima', 15: 'Pará', 16: 'Amapá', 17: 'Tocantins',
    21: 'Maranhão', 22: 'Piauí', 23: 'Ceará', 24: 'Rio Grande do Norte', 25: 'Paraíba', 26: 'Pernambuco',
    27: 'Alagoas', 28: 'Sergipe', 29: 'Bahia', 31: 'Minas Gerais', 32: 'Espírito Santo', 33: 'Rio de Janeiro',
    35: 'São Paulo', 41: 'Paraná', 42: 'Santa Catarina', 43: 'Rio Grande do Sul', 50: 'Mato Grosso do Sul',
    51: 'Mato Grosso', 52: 'Goiás', 53: 'Distrito Federal'
}

# Map department IDs to names
# Only proceed if 'actual_data' was successfully loaded and there's at least one model to compare
if "actual_data" in datasets and any(key.startswith("model_") for key in datasets.keys()):
    actual_data = datasets["actual_data"].copy()
    actual_data["Department"] = actual_data["dep_id"].map(DEP_NAMES)

    # Compute average dengue rates per department
    actual_avg = actual_data.groupby("Department")[["DengRate_all", "DengRate_019"]].mean().reset_index()

    # Merge actual averages with model metric datasets
    merged_datasets = {}
    for model_name, model_df in datasets.items():
        if model_name != "actual_data":
            merged_datasets[model_name] = model_df.merge(actual_avg, on="Department", how="left")

    # Compute statistics for Taylor diagram
    model_stats = {}
    for model_name, df in merged_datasets.items():
        # Handle cases where 'NRMSE All Validation' might have inf values or be empty after dropna
        nrmse_series = df["NRMSE All Validation"].replace([np.inf, -np.inf], np.nan).dropna()
        dengrate_series = df["DengRate_all"].dropna()

        if len(nrmse_series) > 1 and len(dengrate_series) > 1:
            std_dev = nrmse_series.std()
            # Align series for correlation calculation if they have different indices after dropna
            common_index = nrmse_series.index.intersection(dengrate_series.index)
            if len(common_index) > 1:
                correlation = np.corrcoef(nrmse_series.loc[common_index], dengrate_series.loc[common_index])[0, 1]
            else:
                correlation = np.nan # Not enough data for correlation
        else:
            std_dev = np.nan # Not enough data for standard deviation
            correlation = np.nan # Not enough data for correlation

        model_stats[model_name] = {"std_dev": std_dev, "correlation": correlation}

    # Filter out models with NaN stats if any
    valid_model_stats = {name: stats for name, stats in model_stats.items() if not np.isnan(stats["std_dev"]) and not np.isnan(stats["correlation"]) and stats["std_dev"] > 0}

    if valid_model_stats:
        # Convert to arrays for plotting
        labels = list(valid_model_stats.keys())
        std_devs = np.array([valid_model_stats[m]["std_dev"] for m in labels])
        correlations = np.array([valid_model_stats[m]["correlation"] for m in labels])
        ref_std = actual_avg["DengRate_all"].std()  # Reference standard deviation

        # Plot Taylor diagram
        plot_taylor_diagram(std_devs, correlations, ref_std, labels, ["r", "g", "b"][:len(labels)]) # Adjust colors based on number of models
    else:
        print("Not enough valid model data to plot Taylor Diagram.")
else:
    print("Taylor Diagram cannot be plotted because 'actual_data' file is missing or there are no models to compare.")
import math
import pandas as pd # Added this import
import numpy as np # Added this import
import os # Added this import
import matplotlib.pyplot as plt # Added this import

# Reload the datasets
BASE = "/content" # Define BASE path
file_paths = {
    "model_1": os.path.join(BASE, "catboost_lagged_19-03-2025-00-47-00.csv"),
    "model_2": os.path.join(BASE, "catboost_normal26-11-2024-01-03-19.csv"),
    "model_3": os.path.join(BASE, "catboost_search_26-11-2024-02-20-15.csv"),
    "actual_data": os.path.join(BASE, "merged_dataset.csv")
}

def plot_taylor_diagram(std_devs, correlations, ref_std, labels, colors):
    """ Generate a Taylor Diagram manually using Matplotlib """
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, polar=True)

    # Convert correlation to angles (arccosine of correlation)
    angles = np.arccos(correlations)

    # Reference circle (actual standard deviation)
    theta = np.linspace(0, np.pi / 2, 100)
    ax.plot(theta, [ref_std] * 100, "k--", label="Reference")

    # Plot each model's performance
    for i, label in enumerate(labels):
        ax.plot(angles[i], std_devs[i], "o", label=label, color=colors[i], markersize=8)

    # Configure polar plot
    ax.set_xticks(np.arccos([1, 0.9, 0.8, 0.7, 0.6]))  # Correlation markers
    ax.set_xticklabels(["1", "0.9", "0.8", "0.7", "0.6"])
    ax.set_ylim(0, max(std_devs) + 0.05)
    ax.set_yticks(np.linspace(0, max(std_devs), 5))

    # Labels and title
    plt.legend(loc="upper right")
    plt.title("Taylor Diagram for Model Comparison")
    plt.show()

# Load data into a dictionary
datasets = {} # Initialize datasets
for key, path in file_paths.items():
    try:
        datasets[key] = pd.read_csv(path)
    except FileNotFoundError:
        print(f"Warning: File not found for {key} at {path}. Skipping this model/data.")

# Mapping department IDs to names
DEP_NAMES = {
    11: 'Rondônia', 12: 'Acre', 13: 'Amazonas', 14: 'Roraima', 15: 'Pará', 16: 'Amapá', 17: 'Tocantins',
    21: 'Maranhão', 22: 'Piauí', 23: 'Ceará', 24: 'Rio Grande do Norte', 25: 'Paraíba', 26: 'Pernambuco',
    27: 'Alagoas', 28: 'Sergipe', 29: 'Bahia', 31: 'Minas Gerais', 32: 'Espírito Santo', 33: 'Rio de Janeiro',
    35: 'São Paulo', 41: 'Paraná', 42: 'Santa Catarina', 43: 'Rio Grande do Sul', 50: 'Mato Grosso do Sul',
    51: 'Mato Grosso', 52: 'Goiás', 53: 'Distrito Federal'
}

# Map department IDs to names
# Only proceed if 'actual_data' was successfully loaded and there's at least one model to compare
if "actual_data" in datasets and any(key.startswith("model_") for key in datasets.keys()):
    actual_data = datasets["actual_data"].copy()
    actual_data["Department"] = actual_data["dep_id"].map(DEP_NAMES)

    # Compute average dengue rates per department
    actual_avg = actual_data.groupby("Department")[["DengRate_all", "DengRate_019"]].mean().reset_index()

    # Merge actual averages with model metric datasets
    merged_datasets = {}
    for model_name, model_df in datasets.items():
        if model_name != "actual_data":
            merged_datasets[model_name] = model_df.merge(actual_avg, on="Department", how="left")

    # Compute statistics for Taylor diagram
    model_stats = {}
    for model_name, df in merged_datasets.items():
        # Handle cases where 'NRMSE All Validation' might have inf values or be empty after dropna
        nrmse_series = df["NRMSE All Validation"].replace([np.inf, -np.inf], np.nan).dropna()
        dengrate_series = df["DengRate_all"].dropna()

        if len(nrmse_series) > 1 and len(dengrate_series) > 1:
            std_dev = nrmse_series.std()
            # Align series for correlation calculation if they have different indices after dropna
            common_index = nrmse_series.index.intersection(dengrate_series.index)
            if len(common_index) > 1:
                correlation = np.corrcoef(nrmse_series.loc[common_index], dengrate_series.loc[common_index])[0, 1]
            else:
                correlation = np.nan # Not enough data for correlation
        else:
            std_dev = np.nan # Not enough data for standard deviation
            correlation = np.nan # Not enough data for correlation

        model_stats[model_name] = {"std_dev": std_dev, "correlation": correlation}

    # Filter out models with NaN stats if any
    valid_model_stats = {name: stats for name, stats in model_stats.items() if not np.isnan(stats["std_dev"]) and not np.isnan(stats["correlation"]) and stats["std_dev"] > 0}

    if valid_model_stats:
        # Convert to arrays for plotting
        labels = list(valid_model_stats.keys())
        std_devs = np.array([valid_model_stats[m]["std_dev"] for m in labels])
        correlations = np.array([valid_model_stats[m]["correlation"] for m in labels])
        ref_std = actual_avg["DengRate_all"].std()  # Reference standard deviation

        # Plot Taylor diagram
        plot_taylor_diagram(std_devs, correlations, ref_std, labels, ["r", "g", "b"][:len(labels)]) # Adjust colors based on number of models
    else:
        print("Not enough valid model data to plot Taylor Diagram.")
else:
    print("Taylor Diagram cannot be plotted because 'actual_data' file is missing or there are no models to compare.")
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

BASE = "/content"

files = {
    'LSTM': os.path.join(BASE, 'LSTM_Model_search_lagged_18-03-2025-20-16-03.csv'), # Updated filename
    'TCN': os.path.join(BASE, 'TCN_model_search_lagged_18-03-2025-21-59-40.csv'),   # Updated filename
    'TFT': os.path.join(BASE, 'TFT_model_lagged_18-03-2025-22-51-57.csv'),
    'CatBoost': os.path.join(BASE, 'catboost_lagged_19-03-2025-00-47-00.csv')
}

# Load and preview data, handling missing files gracefully
dataframes = {}
for model, path in files.items():
    try:
        dataframes[model] = pd.read_csv(path)
    except FileNotFoundError:
        print(f"Warning: File not found for {model} at {path}. Skipping this model.")

# Check if any dataframes were loaded
if not dataframes:
    print("Error: No model dataframes could be loaded. Cannot proceed with visualization.")
else:
    metrics = [
        'NRMSE 0-19 Validation',
        'NRMSE All Validation',
        'MAE (DengRate_019) Val',
        'MAE (DengRate_all) Val'
    ]
    # Extract and safely convert relevant columns to numeric for all models
    clean_comparison_data = []

    for model, df in dataframes.items():
        for metric in metrics:
            if metric in df.columns:
                # Convert column to numeric, coerce errors (e.g., non-numeric strings become NaN)
                numeric_values = pd.to_numeric(df[metric], errors='coerce')
                avg_val = numeric_values.dropna().mean()
                clean_comparison_data.append({'Model': model, 'Metric': metric, 'Value': avg_val})

    for model, df in dataframes.items():
        if 'NRMSE All Validation' not in df.columns:
            print(f"{model} is missing 'NRMSE All Validation' column")
        else:
            values = pd.to_numeric(df['NRMSE All Validation'], errors='coerce').dropna()
            if values.empty:
                print(f"{model} has only NaNs or invalid values in 'NRMSE All Validation'")

    # Create DataFrame from clean data
    clean_comparison_df = pd.DataFrame(clean_comparison_data)

    # Split the data
    nrmse_df = clean_comparison_df[clean_comparison_df['Metric'].str.contains('NRMSE')]
    mae_df = clean_comparison_df[clean_comparison_df['Metric'].str.contains('MAE')]

    # Plot NRMSE
    plt.figure(figsize=(12, 4))
    sns.barplot(data=nrmse_df, x='Metric', y='Value', hue='Model')
    plt.title('NRMSE Validation Metric Comparison')
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.grid(axis='y')
    plt.show()

    # Plot MAE
    plt.figure(figsize=(12, 4))
    sns.barplot(data=mae_df, x='Metric', y='Value', hue='Model')
    plt.title('MAE Validation Metric Comparison')
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.grid(axis='y')
    plt.show()


    # Calculate accuracy (%) relative to the worst error (higher is better)
    # This part might fail if 'Ensemble1' is still referenced and not in dataframes
    # We need to adapt this section to handle cases where Ensemble1 is not present
    if 'Ensemble1' in clean_comparison_df['Model'].unique():
        accuracy_df = clean_comparison_df.pivot(index='Model', columns='Metric', values='Value')
        accuracy_percent = (1 - (accuracy_df / accuracy_df.max())) * 100

        # Calculate improvement of Ensemble over other models
        ensemble_accuracy = accuracy_percent.loc['Ensemble1']
        improvement_vs_others = (ensemble_accuracy - accuracy_percent.drop(index='Ensemble1')) / accuracy_percent.drop(index='Ensemble1') * 100

        print(accuracy_percent.round(2), improvement_vs_others.round(2))
    else:
        print("Skipping accuracy and improvement calculations as 'Ensemble1' model data is not available.")


# We'll compute absolute accuracy assuming the following:
# - NRMSE is normalized: accuracy = (1 - NRMSE) * 100
# - MAE = avg(|prediction - actual|); if we estimate the average actual value (mean_actual),
#   then accuracy = (1 - MAE / mean_actual) * 100

# First, gather mean MAE and NRMSE values from cleaned data
accuracy_summary = clean_comparison_df.pivot(index='Model', columns='Metric', values='Value')

# Assume estimated average true dengue count values based on typical ranges
# These are rough domain-informed estimates (can be refined with true data):
avg_actual_019 = 100   # Average dengue count in 0–19 age group
avg_actual_all = 120   # Average dengue count across all age groups

# Compute true accuracy
accuracy_absolute = pd.DataFrame(index=accuracy_summary.index)
accuracy_absolute['MAE_019_Accuracy (%)'] = (1 - (accuracy_summary['MAE (DengRate_019) Val'] / avg_actual_019)) * 100
accuracy_absolute['MAE_all_Accuracy (%)'] = (1 - (accuracy_summary['MAE (DengRate_all) Val'] / avg_actual_all)) * 100
accuracy_absolute['NRMSE_all_Accuracy (%)'] = (1 - accuracy_summary['NRMSE All Validation']) * 100

# Determine the best model (highest average accuracy across metrics)
accuracy_absolute['Average Accuracy (%)'] = accuracy_absolute.mean(axis=1)
best_model = accuracy_absolute['Average Accuracy (%)'].idxmax()
best_accuracy = accuracy_absolute.loc[best_model]

# Calculate improvement of best model over others (in percentage points)
improvement_points = best_accuracy['Average Accuracy (%)'] - accuracy_absolute['Average Accuracy (%)']

accuracy_absolute.round(2), best_model, improvement_points.round(2)
# Out:
# /tmp/ipykernel_4488/3513274643.py:69: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_plot, x="State", y="Value", hue="Model", ci=None)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# Skipping accuracy and improvement calculations as 'Ensemble1' model data is not available.
# (          MAE_019_Accuracy (%)  MAE_all_Accuracy (%)  NRMSE_all_Accuracy (%)  \
#  Model
#  CatBoost                 95.40                 95.96                   97.45
#  LSTM                     55.00                 64.43                   72.14
#  TCN                      91.50                 91.30                   94.97
#  TFT                      74.78                 89.59                   93.03
#
#            Average Accuracy (%)
#  Model
#  CatBoost                 96.27
#  LSTM                     63.86
#  TCN                      92.59
#  TFT                      85.80  ,
#  'CatBoost',
#  Model
#  CatBoost     0.00
#  LSTM        32.41
#  TCN          3.68
#  TFT         10.47
#  Name: Average Accuracy (%), dtype: float64)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

print(os.listdir("/content/drive/MyDrive"))
# Out:
# ['Untitled0.ipynb', 'Classroom', 'IMG_20200909_230254.jpg', 'IMG_20200910_230453.jpg', 'New Doc 2020-09-13_2.jpg', 'New Doc 2020-09-13_1.jpg', 'New Doc 2020-09-13_3.jpg', 'New Doc 2020-09-16_1.jpg', 'New Doc 2020-09-16_2.jpg', 'New Doc 2020-09-22_4.jpg', 'New Doc 2020-09-22_2.jpg', 'New Doc 2020-09-30_1.jpg', 'New Doc 2020-09-30_3.jpg', 'New Doc 2020-09-30_2.jpg', 'New Doc 2020-09-30_4.jpg', 'New Doc 2020-10-06_1.jpg', 'New Doc 2020-10-06_2.jpg', 'New Doc 2020-10-06_3.jpg', 'New Doc 2020-10-11_1.jpg', 'New Doc 2020-10-11_2.jpg', 'New Doc 2020-10-18 (1)_1.jpg', 'New Doc 2020-10-18 (1)_2.jpg', 'New Doc 2020-10-22 (1)_1.jpg', 'New Doc 2020-10-22 (1)_2.jpg', 'New Doc 2020-10-22 (1)_3.jpg', 'New Doc 2020-11-05 (1).pdf', 'Shadab sir', 'New Doc 2020-11-10.pdf', 'New Doc 2020-11-28.pdf', 'assignment 10(A).pdf', '1st internal test drawing.pdf', '10b eg.pdf', '11 section of solids.pdf', '12 solids.pdf', 'PHYSICS 101(2).pdf', '13A ~by Shams Tahzib~.pdf', '2nd Internal TEST ~shams Tahzib~ (2).pdf', 'Untitled spreadsheet.gsheet', 'certificate (3).pdf', 'certificate.pdf', 'certificate (2).pdf', 'Mohamad Tahzibul Haque Siddiqui_ERP BN', 'MOHAMAD TAHZIBUL HAQUE SIDDIQUE_169350 (1).pdf', 'MOHAMAD TAHZIBUL HAQUE SIDDIQUE_169350.pdf', 'certificate of Mohamad Tahzibul Haque Siddique.pdf', 'Math 2.pdf', '2nd dose.pdf', 'Scanned_20211102-1639.pdf', 'Scanned_20211102-1641.pdf', '210 Shams Tahzib  maths exam 3.pdf', 'Matlab.docx', '210-Shams Tahzib MATLAB.pdf', '210-Shams Tahzib MATLAB (3).docx', '210-Shams Tahzib MATLAB-converted.pdf', '210-Shams Tahzib MATLAB (2).docx', '210-Shams Tahzib MATLAB (1).docx', '210-Shams Tahzib MATLAB.docx', '210-Shams Tahzib MATLAB.gdoc', '210 SHAMS TAHZIB (MATLAB).pdf', '210 - SHAMS TAHZIB - DSA ASSIGNMENT.pdf', 'Untitled form.gform', 'SECTION-D E-mail ID for DSA.gform', 'Analog electronics Lab BTCSE 307 section D.gdoc', 'SECTION-D E-mail ID for DSA (Responses).gsheet', '2020-310-210 SHAMS TAHZIB (IT).pdf', '2020-310-210 SHAMS TAHZIB (IT) (1).pdf', '2020-310-210 SHAMS TAHZIB (LAB)-converted (1).pdf', '2020-310-210 SHAMS TAHZIB (LAB)-converted (2).pdf', '2020-310-210 SHAMS TAHZIB (LAB WORK).pdf', 'CamScanner 03-16-2022 12.50.pdf', '2020-310-210 Shams Tahzib Re Admission form.pdf', '2020-310-210-Shams Tahzib (Notemaking).docx', 'Even sem 2022 B.Tech (CSE) 4 sem.pdf', 'Contact Information.gform', 'Sundar Pics', 'Google Keep Document.gdoc', 'craftinginterpreters.7z', 'Shams Tahzib all certificates.pdf', 'Shams Tahzib Certificates.pdf', 'Section D MOOCS.gform', 'Section D MOOCS (Responses).gsheet', 'Untitled document (8).gdoc', 'ShamsProject.zip', 'jpeg-optimizer_1000114797.jpg', 'WEBREC.mp4', 'react-auth-main (1).zip', 'preview (1)', 'react-auth-main.zip', 'project final', 'preview', 'Paytm_QRcode (1).png', 'Screenshot_2024-06-03-23-22-12-85_49b96b5fbae0d12a18edc4a3afe0dfd9.jpg', '2024-06-07 22-52-04.mp4', 'Shams Tahzib Resume ', 'MOOCSubListE2025_copy.pdf', '45 Days Question Marathon.gsheet', 'Colab Notebooks', 'IPR 1.gdoc', 'IPR 2.gdoc', 'IPR 3.gdoc', 'Screenshot_2025-10-29-15-37-49-40_92460851df6f172a4592fca41cc2d2e6.jpg', 'Screenshot_2025-10-29-15-42-07-38_f541918c7893c52dbd1ee5d319333948.jpg', 'Screenshot_2025-10-29-15-43-53-44_49b96b5fbae0d12a18edc4a3afe0dfd9.jpg', 'Anomaly_Detection_Academic_Presentation (1).pptx', 'Neural_Networks_for_Deep_Learning_Academic_Presentation.pptx', 'Dimensionality_Reduction_Academic_Presentation.pptx', 'Multiple Choice Quiz.gform', 'Quiz 1.gform', 'COA Quiz 1.gform', 'Untitled document (7).gdoc', 'COA 1.gform', 'Untitled document (6).gdoc', 'COA 1 Set A.gform', 'DENGUESCOPE: Leveraging Geospatial and Trends Data to Predict and Mitigate Dengue Outbreaks with AI Models (1).gdoc', 'Untitled document (5).gdoc', 'Quiz 6.gform', 'Untitled document (4).gdoc', 'Computer Organization & Architecture (COA) Quiz (1).gform', 'Computer Organization & Architecture (COA) Quiz.gform', 'Untitled document (3).gdoc', '50 MSQs (1).gform', '50 MSQs.gform', 'Assignment 9', 'Untitled document (2).gdoc', 'MCQs ...

# %%
import os

print(os.listdir("/content/drive/MyDrive/DengueScope-main"))
# Out:
# ['README.md', '.gitattributes', '.gitignore', 'dengue_brazil_improved.html', 'metrics_visualiser.ipynb', 'requirements.txt', 'dengue_brazil_with_metrics.html', 'maps.ipynb', 'serpapi_results_filtered', 'code', 'serpapi_results_converted', 'guide', 'serpapi_results_cleaned', 'filtered_results', 'serpapi_results', '.venv', 'google trends', 'baseline_metrics']

# %%
import os

BASE = "/content/drive/MyDrive/DengueScope-main"

for root, dirs, files in os.walk(BASE):
    for f in files:
        if "merged" in f.lower() or "dataset" in f.lower():
            print(os.path.join(root, f))
# Out:
# /content/drive/MyDrive/DengueScope-main/code/datasetHandler.py
# /content/drive/MyDrive/DengueScope-main/code/__pycache__/datasetHandler.cpython-310.pyc
# /content/drive/MyDrive/DengueScope-main/code/.ipynb_checkpoints/datasetHandler-checkpoint.py
# /content/drive/MyDrive/DengueScope-main/google trends/merged_dataset_lagged.csv
# /content/drive/MyDrive/DengueScope-main/google trends/merged_dataset.csv.schema.json
# /content/drive/MyDrive/DengueScope-main/google trends/merged_dataset.csv.table.json
# /content/drive/MyDrive/DengueScope-main/google trends/merged_dataset.csv
# /content/drive/MyDrive/DengueScope-main/google trends/not_merged_nogt_lagged.csv
# /content/drive/MyDrive/DengueScope-main/google trends/merged_dataset_lagged_noewma_norollavg_nooriginal.csv
# /content/drive/MyDrive/DengueScope-main/google trends/merged_test1.csv
# /content/drive/MyDrive/DengueScope-main/google trends/merged_dataset_lagged_nooriginal.csv
# /content/drive/MyDrive/DengueScope-main/google trends/merged_dataset_lagged_noewma_norollavg.csv
# /content/drive/MyDrive/DengueScope-main/google trends/merged_dataset_lagged_gtonly.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_dataset_set2-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_dataset_lagged-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_dataset-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_dataset_set1-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_test1-checkpoint.csv

# %%
import pandas as pd

DATA_PATH = "/content/drive/MyDrive/DengueScope-main/google trends/merged_dataset.csv"

df = pd.read_csv(DATA_PATH)

print(df.shape)
print(df.columns)
print(df.head())
# Out:
# (5184, 41)
# Index(['Year', 'dep_id', 't_fundc_ocup18m', 't_medioc_ocup18m',
#        'PopTotal_Urban_UF', 'PopTotal_Rural_UF', 'total_precipitation_d',
#        'surface_pressure_d', 'area_km2', 'humidity_d', 'temperature_2m_d',
#        'min_temperature_2m_d', 'CNN_all', 'CNN_0-19', 'Month', 'cases20_99',
#        'cases0_19', 'RandEffects1', 'RandEffects2', 'RandEffects3',
#        'PCA0-Climatic', 'PCA1-Climatic', 'PCA2-Climatic', 'PCA3-Climatic',
#        'PCA0-Geo', 'PCA1-Geo', 'PCA2-Geo', 'PCA3-Geo', 'PCA4-Geo', 'PCA5-Geo',
#        'PCA0-Socio', 'PCA1-Socio', 'PCA2-Socio', 'PCA3-Socio', 'PCA4-Socio',
#        'PCA5-Socio', 'mosquito_interest', 'sintomas_dengue_interest',
#        'dengue_interest', 'DengRate_all', 'DengRate_019'],
#       dtype='object')
#    Year  dep_id  t_fundc_ocup18m  t_medioc_ocup18m  PopTotal_Urban_UF  \
# 0  2004      11         0.206751           0.12853           0.020497
# 1  2004      11         0.206751           0.12853           0.020497
# 2  2004      11         0.206751           0.12853           0.020497
# 3  2004      11         0.206751           0.12853           0.020497
# 4  2004      11         0.206751           0.12853           0.020497
#
#    PopTotal_Rural_UF  total_precipitation_d  surface_pressure_d  area_km2  \
# 0           0.089637               0.561331            0.804656  0.149352
# 1           0.089637               0.457736            0.817198  0.149352
# 2           0.089637               0.419033            0.812810  0.149352
# 3           0.089637               0.261944            0.817030  0.149352
# 4           0.089637               0.104751            0.837945  0.149352
#
#    humidity_d  ...  PCA1-Socio  PCA2-Socio  PCA3-Socio  PCA4-Socio  \
# 0    0.964033  ...    0.096634    0.179967    0.325246    0.604686
# 1    0.945382  ...    0.096634    0.179967    0.325246    0.604686
# 2    0.953611  ...    0.096634    0.179967    0.325246    0.604686
# 3    0.956150  ...    0.096634    0.179967    0.325246    0.604686
# 4    0.898510  ...    0.096634    0.179967    0.325246    0.604686
#
#    PCA5-Socio  mosquito_interest  sintomas_dengue_interest  dengue_interest  \
# 0    0.076292                0.0                       0.0              0.0
# 1    0.076292                0.0                       0.0              0.0
# 2    0.076292                0.0                       0.0              0.0
# 3    0.076292                0.0                       0.0              0.0
# 4    0.076292                0.0                       0.0              0.0
#
#    DengRate_all  DengRate_019
# 0      0.020683      0.014735
# 1      0.016590      0.014934
# 2      0.013438      0.011748
# 3      0.005419      0.003783
# 4      0.003097      0.002389
#
# [5 rows x 41 columns]

# %%
from sklearn.model_selection import train_test_split

# Define target
target = "DengRate_all"

# Drop unnecessary columns (IMPORTANT)
drop_cols = ["DengRate_all", "DengRate_019"]

X = df.drop(columns=drop_cols)
y = df[target]

# Train-test split (time series → no shuffle)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (4147, 39)
# X_test: (1037, 39)
# y_train: (4147,)
# y_test: (1037,)

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 8.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.10

# %%
from catboost import CatBoostRegressor

# Initialize model
cat = CatBoostRegressor(
    iterations=200,
    learning_rate=0.05,
    depth=6,
    verbose=0
)

# Train
cat.fit(X_train, y_train)

# Predict
y_pred_cat = cat.predict(X_test)

print("Predictions shape:", y_pred_cat.shape)
print("First 5 predictions:", y_pred_cat[:5])
# Out:
# Predictions shape: (1037,)
# First 5 predictions: [ 2.09715306e-04  2.83684834e-05  9.17568735e-05 -5.13231095e-04
#  -7.23923807e-04]

# %%
import pandas as pd
import os

# Create folder to store predictions
SAVE_PATH = "/content/drive/MyDrive/DengueScope-main/predictions"
os.makedirs(SAVE_PATH, exist_ok=True)

# Save CatBoost predictions
df_cat = pd.DataFrame({
    "True DengRate_all": y_test.values,
    "Predicted DengRate_all": y_pred_cat
})

file_path = SAVE_PATH + "/catboost_predictions.csv"
df_cat.to_csv(file_path, index=False)

print("Saved at:", file_path)
print(df_cat.head())
# Out:
# Saved at: /content/drive/MyDrive/DengueScope-main/predictions/catboost_predictions.csv
#    True DengRate_all  Predicted DengRate_all
# 0           0.000028                0.000210
# 1           0.000041                0.000028
# 2           0.000028                0.000092
# 3           0.000041               -0.000513
# 4           0.000055               -0.000724

# %%
import pandas as pd

TCN_PATH = "/content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-10-11-2024-17-53-06.csv"

tcn_df = pd.read_csv(TCN_PATH)

print("Shape:", tcn_df.shape)
print("Columns:", tcn_df.columns)
print(tcn_df.head())
# Out:
# Shape: (972, 6)
# Columns: Index(['True DengRate_all', 'Predicted DengRate_all', 'True DengRate_019',
#        'Predicted DengRate_019', 'MAE (DengRate_all)', 'MAE (DengRate_019)'],
#       dtype='object')
#    True DengRate_all  Predicted DengRate_all  True DengRate_019  \
# 0           0.032628                0.035182           0.031062
# 1           0.028203                0.025340           0.036438
# 2           0.020461                0.019705           0.020310
# 3           0.008185                0.033186           0.007766
# 4           0.005032                0.025785           0.006372
#
#    Predicted DengRate_019  MAE (DengRate_all)  MAE (DengRate_019)
# 0                0.032234            0.002554            0.001172
# 1                0.025207            0.002863            0.011231
# 2                0.020354            0.000756            0.000044
# 3                0.035940            0.025001            0.028174
# 4                0.027729            0.020753            0.021357

# %%
import numpy as np

# Extract TCN
y_true_tcn = tcn_df["True DengRate_all"].values
y_pred_tcn = tcn_df["Predicted DengRate_all"].values

# Use last 972 values from CatBoost (to match time alignment)
y_true_cat = y_test.values[-972:]
y_pred_cat = y_pred_cat[-972:]

print("TCN:", len(y_true_tcn))
print("CatBoost:", len(y_true_cat))
# Out:
# TCN: 972
# CatBoost: 972

# %%
import numpy as np
from scipy import stats

def dm_test(e1, e2):
    d = e1**2 - e2**2
    dm_stat = np.mean(d) / np.sqrt(np.var(d)/len(d))
    p_value = 2 * (1 - stats.norm.cdf(abs(dm_stat)))
    return dm_stat, p_value

# Errors
e_cat = y_true_cat - y_pred_cat
e_tcn = y_true_tcn - y_pred_tcn

# DM Test
dm_stat, p_value = dm_test(e_cat, e_tcn)

print("DM Statistic:", dm_stat)
print("p-value:", p_value)
# Out:
# DM Statistic: 1.038541328205021
# p-value: 0.2990181048934777

# %%
import numpy as np
import pandas as pd

# Simple average ensemble
y_pred_ens = (y_pred_cat + y_pred_tcn) / 2

# Save ensemble
df_ens = pd.DataFrame({
    "True DengRate_all": y_true_cat,
    "Predicted DengRate_all": y_pred_ens
})

SAVE_PATH = "/content/drive/MyDrive/DengueScope-main/predictions/ensemble_predictions.csv"
df_ens.to_csv(SAVE_PATH, index=False)

print("Saved ensemble at:", SAVE_PATH)
print(df_ens.head())
# Out:
# Saved ensemble at: /content/drive/MyDrive/DengueScope-main/predictions/ensemble_predictions.csv
#    True DengRate_all  Predicted DengRate_all
# 0           0.000277                0.017171
# 1           0.000622                0.012324
# 2           0.004300                0.010735
# 3           0.008075                0.019378
# 4           0.009223                0.015857

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# reshape for scaler
scaler = MinMaxScaler()

# stack predictions
stack = np.vstack((y_pred_cat, y_pred_tcn)).T

# normalize both
stack_scaled = scaler.fit_transform(stack)

# split back
y_cat_scaled = stack_scaled[:, 0]
y_tcn_scaled = stack_scaled[:, 1]

# ensemble (correct)
y_pred_ens = (y_cat_scaled + y_tcn_scaled) / 2

# %%
import pandas as pd

df_ens = pd.DataFrame({
    "True DengRate_all": y_true_cat,
    "Predicted DengRate_all": y_pred_ens
})

SAVE_PATH = "/content/drive/MyDrive/DengueScope-main/predictions/ensemble_predictions_fixed.csv"
df_ens.to_csv(SAVE_PATH, index=False)

print("Saved fixed ensemble at:", SAVE_PATH)
print(df_ens.head())
# Out:
# Saved fixed ensemble at: /content/drive/MyDrive/DengueScope-main/predictions/ensemble_predictions_fixed.csv
#    True DengRate_all  Predicted DengRate_all
# 0           0.000277                0.042748
# 1           0.000622                0.033693
# 2           0.004300                0.031184
# 3           0.008075                0.048107
# 4           0.009223                0.041577

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import numpy as np

# reshape for LSTM
X_train_lstm = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm  = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))

model_lstm = Sequential([
    LSTM(32, input_shape=(X_train.shape[1], 1)),
    Dense(1)
])

model_lstm.compile(optimizer='adam', loss='mse')

model_lstm.fit(X_train_lstm, y_train, epochs=5, verbose=0)

y_pred_lstm = model_lstm.predict(X_test_lstm).flatten()

print("Shape:", y_pred_lstm.shape)
print("First 5:", y_pred_lstm[:5])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Shape: (1037,)
# First 5: [0.02431452 0.02168881 0.02226709 0.02217194 0.02123393]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input

# Scale target
scaler_y = MinMaxScaler()

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1, 1))

# reshape X
X_train_lstm = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm  = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))

# Build model (clean version)
model_lstm = Sequential([
    Input(shape=(X_train.shape[1], 1)),
    LSTM(32),
    Dense(1)
])

model_lstm.compile(optimizer='adam', loss='mse')

# Train
model_lstm.fit(X_train_lstm, y_train_scaled, epochs=5, verbose=0)

# Predict
y_pred_lstm_scaled = model_lstm.predict(X_test_lstm)

# Convert back to original scale
y_pred_lstm = scaler_y.inverse_transform(y_pred_lstm_scaled).flatten()

print("Shape:", y_pred_lstm.shape)
print("First 5:", y_pred_lstm[:5])
print("Actual first 5:", y_test.values[:5])
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Shape: (1037,)
# First 5: [0.01550977 0.01311356 0.01364556 0.01371301 0.01356568]
# Actual first 5: [2.76557875e-05 4.14836812e-05 2.76557875e-05 4.14836812e-05
#  5.53115750e-05]

# %%
import numpy as np

# baseline = previous value
y_pred_base = np.roll(y_test.values, 1)
y_pred_base[0] = y_test.values[0]

print("First 5 baseline:", y_pred_base[:5])
# Out:
# First 5 baseline: [2.76557875e-05 2.76557875e-05 4.14836812e-05 2.76557875e-05
#  4.14836812e-05]

# %%
# Use FULL CatBoost predictions (not trimmed)
y_pred_cat_full = y_pred_cat_full = cat.predict(X_test)

print(len(y_pred_cat_full), len(y_pred_base))
# Out:
# 1037 1037

# %%
y_pred_ens = (y_pred_cat_full + y_pred_base) / 2

import pandas as pd

df_ens = pd.DataFrame({
    "True DengRate_all": y_test.values,
    "Predicted DengRate_all": y_pred_ens
})

SAVE_PATH = "/content/drive/MyDrive/DengueScope-main/predictions/ensemble_valid.csv"
df_ens.to_csv(SAVE_PATH, index=False)

print("Saved:", SAVE_PATH)
print(df_ens.head())
# Out:
# Saved: /content/drive/MyDrive/DengueScope-main/predictions/ensemble_valid.csv
#    True DengRate_all  Predicted DengRate_all
# 0           0.000028                0.000119
# 1           0.000041                0.000028
# 2           0.000028                0.000067
# 3           0.000041               -0.000243
# 4           0.000055               -0.000341

# %%
import numpy as np
from scipy import stats

def dm_test(e1, e2):
    d = e1**2 - e2**2
    dm_stat = np.mean(d) / np.sqrt(np.var(d)/len(d))
    p_value = 2 * (1 - stats.norm.cdf(abs(dm_stat)))
    return dm_stat, p_value

# Errors
e_ens = y_test.values - y_pred_ens
e_cat = y_test.values - y_pred_cat_full

# DM Test
dm_stat, p_value = dm_test(e_ens, e_cat)

print("DM Statistic:", dm_stat)
print("p-value:", p_value)
# Out:
# DM Statistic: -0.23441651507394726
# p-value: 0.8146616386184431

# %%
# Errors
e_lstm = y_test.values - y_pred_lstm
e_ens  = y_test.values - y_pred_ens

# DM test
dm_stat_lstm, p_lstm = dm_test(e_ens, e_lstm)

print("DM (Ensemble vs LSTM):", dm_stat_lstm)
print("p-value:", p_lstm)
# Out:
# DM (Ensemble vs LSTM): -5.836415925352157
# p-value: 5.333565589182854e-09

# %%
import numpy as np

# residuals
residuals = y_test.values - y_pred_ens

# standard deviation
std = np.std(residuals)

# 95% confidence interval
lower = y_pred_ens - 1.96 * std
upper = y_pred_ens + 1.96 * std

# PICP
picp = np.mean((y_test.values >= lower) & (y_test.values <= upper)) * 100

# MPIW
mpiw = np.mean(upper - lower)

print("PICP:", picp)
print("MPIW:", mpiw)
# Out:
# PICP: 97.10703953712633
# MPIW: 0.1385083565431613

# %%
# CatBoost uncertainty
residuals_cat = y_test.values - y_pred_cat_full
std_cat = np.std(residuals_cat)

lower_cat = y_pred_cat_full - 1.96 * std_cat
upper_cat = y_pred_cat_full + 1.96 * std_cat

picp_cat = np.mean((y_test.values >= lower_cat) & (y_test.values <= upper_cat)) * 100
mpiw_cat = np.mean(upper_cat - lower_cat)

print("CatBoost PICP:", picp_cat)
print("CatBoost MPIW:", mpiw_cat)
# Out:
# CatBoost PICP: 96.62487945998072
# CatBoost MPIW: 0.14181059675689234

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Define peak threshold (top 25%)
threshold = np.percentile(y_test.values, 75)

peak = y_test.values >= threshold
non_peak = y_test.values < threshold

def metrics(y_t, y_p):
    rmse = np.sqrt(mean_squared_error(y_t, y_p))
    mae = mean_absolute_error(y_t, y_p)
    return rmse, mae

# Compute metrics
rmse_peak, mae_peak = metrics(y_test.values[peak], y_pred_ens[peak])
rmse_non, mae_non = metrics(y_test.values[non_peak], y_pred_ens[non_peak])

print("Peak RMSE:", rmse_peak)
print("Peak MAE:", mae_peak)
print("Non-Peak RMSE:", rmse_non)
print("Non-Peak MAE:", mae_non)
# Out:
# Peak RMSE: 0.06983858095330236
# Peak MAE: 0.034423023333409186
# Non-Peak RMSE: 0.006022540090716594
# Non-Peak MAE: 0.002751666050613177

# %%
import numpy as np

# Mean values
mean_peak = np.mean(y_test.values[peak])
mean_non  = np.mean(y_test.values[non_peak])

# NRMSE
nrmse_peak = (rmse_peak / mean_peak) * 100
nrmse_non  = (rmse_non / mean_non) * 100

print("Peak NRMSE:", nrmse_peak)
print("Non-Peak NRMSE:", nrmse_non)
# Out:
# Peak NRMSE: 48.485630036571116
# Non-Peak NRMSE: 90.09253919239586

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

def compute_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mae

results = {}

for h in [1, 2, 3]:
    y_true_h = y_test.values[h:]
    y_pred_h = y_pred_ens[:-h]

    rmse, mae = compute_metrics(y_true_h, y_pred_h)

    results[h] = (rmse, mae)

    print(f"Horizon t+{h}")
    print("RMSE:", rmse)
    print("MAE:", mae)
    print("------")
# Out:
# Horizon t+1
# RMSE: 0.06739669313132352
# MAE: 0.025826305458700124
# ------
# Horizon t+2
# RMSE: 0.0950574456404157
# MAE: 0.03924609939287128
# ------
# Horizon t+3
# RMSE: 0.113336277103165
# MAE: 0.04962692364840055
# ------

# %%
import numpy as np
from scipy.stats import pearsonr

results = {}

for h in [1, 2, 3]:
    y_true_h = y_test.values[h:]
    y_pred_h = y_pred_ens[:-h]

    r, _ = pearsonr(y_true_h, y_pred_h)

    print(f"Horizon t+{h} Pearson r:", r)
# Out:
# Horizon t+1 Pearson r: 0.7315588780270066
# Horizon t+2 Pearson r: 0.450626945629037
# Horizon t+3 Pearson r: 0.2129543072309507

# %%
import time
from catboost import CatBoostRegressor

# Reinitialize model
cat_time = CatBoostRegressor(
    iterations=200,
    learning_rate=0.05,
    depth=6,
    verbose=0
)

# Training time
start = time.time()
cat_time.fit(X_train, y_train)
train_time = time.time() - start

# Inference time
start = time.time()
_ = cat_time.predict(X_test)
infer_time = (time.time() - start) / len(X_test)

print("Training time (hours):", train_time / 3600)
print("Inference time (ms/sample):", infer_time * 1000)
# Out:
# Training time (hours): 0.0012407361798816257
# Inference time (ms/sample): 0.0026099592188630065

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input

# Scale target
scaler_y = MinMaxScaler()

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1, 1))

# Reshape input
X_train_lstm = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm  = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))

# Build model
model_lstm = Sequential([
    Input(shape=(X_train.shape[1], 1)),
    LSTM(64),
    Dense(1)
])

model_lstm.compile(optimizer='adam', loss='mse')

# Train
model_lstm.fit(X_train_lstm, y_train_scaled, epochs=10, verbose=0)

# Predict
y_pred_lstm_scaled = model_lstm.predict(X_test_lstm)
y_pred_lstm = scaler_y.inverse_transform(y_pred_lstm_scaled).flatten()

print("Shape:", y_pred_lstm.shape)
print("First 5 predictions:", y_pred_lstm[:5])
print("First 5 actual:", y_test.values[:5])
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Shape: (1037,)
# First 5 predictions: [0.02071079 0.01874339 0.01921144 0.0190939  0.01835389]
# First 5 actual: [2.76557875e-05 4.14836812e-05 2.76557875e-05 4.14836812e-05
#  5.53115750e-05]

# %%
import os

BASE = "/content/drive/MyDrive/DengueScope-main"

for root, dirs, files in os.walk(BASE):
    for f in files:
        if "pred" in f.lower() or "result" in f.lower():
            print(os.path.join(root, f))
# Out:
# /content/drive/MyDrive/DengueScope-main/code/raw_ensemble_predictions_Brazil.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/ensemble_results_07-05-2025-15-39-09.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/ensemble_results_01-05-2025-16-29-44.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/ensemble_results_01-05-2025-20-19-39.csv
# /content/drive/MyDrive/DengueScope-main/code/.ipynb_checkpoints/model_predictions_metrics-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/sympy/polys/multivariate_resultants.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/sympy/polys/subresultants_qq_zz.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/sympy/polys/tests/test_subresultants_qq_zz.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/sympy/polys/tests/test_multivariate_resultants.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/sympy/polys/tests/__pycache__/test_multivariate_resultants.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/sympy/polys/tests/__pycache__/test_subresultants_qq_zz.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/sympy/polys/__pycache__/multivariate_resultants.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/sympy/polys/__pycache__/subresultants_qq_zz.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/setuptools/_distutils/versionpredicate.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/setuptools/_distutils/tests/test_versionpredicate.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/setuptools/_distutils/tests/__pycache__/test_versionpredicate.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/setuptools/_distutils/__pycache__/versionpredicate.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/pyparsing/results.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/pyparsing/__pycache__/results.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/networkx/algorithms/link_prediction.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/networkx/algorithms/__pycache__/link_prediction.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/networkx/algorithms/tests/test_link_prediction.py
# /content/drive/MyDrive/DengueScope-main/.venv/Lib/site-packages/networkx/algorithms/tests/__pycache__/test_link_prediction.cpython-312.pyc
# /content/drive/MyDrive/DengueScope-main/predictions/catboost_predictions.csv
# /content/drive/MyDrive/DengueScope-main/predictions/ensemble_predictions.csv
# /content/drive/MyDrive/DengueScope-main/predictions/ensemble_predictions_fixed.csv

# %%
for root, dirs, files in os.walk(BASE):
    for f in files:
        if f.endswith(".csv"):
            print(os.path.join(root, f))
# Out:
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/ES_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MG_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AL_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AP_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AC_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AM_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SC_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RJ_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PI_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AC_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AP_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/GO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AM_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/CE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/TO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/TO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MT_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MS_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MT_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SC_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RS_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/BA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AM_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/DF_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AL_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PR_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/CE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RR_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RN_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/BA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RJ_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MT_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RN_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/ES_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/ES_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PI_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AC_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RN_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/DF_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PB_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MG_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/DF_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SP_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/BA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PB_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/GO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/TO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/CE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MS_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MG_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RS_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RR_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PR_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PB_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MS_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/GO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/AL_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SC_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/SP_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RS_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/RJ_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/MA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/PI_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/TO_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/AM_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/AM_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/AC_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/AM_sintomas_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/DF_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/TO_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/RO_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/TO_sintomas_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/DF_sintomas_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/DF_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_filtered/.ipynb_checkpoints/AC_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/reduced.csv
# /content/drive/MyDrive/DengueScope-main/code/raw_ensemble_predictions_Brazil.csv
# /content/drive/MyDrive/DengueScope-main/code/out.csv
# /content/drive/MyDrive/DengueScope-main/code/reduced_2004_2019.csv
# /content/drive/MyDrive/DengueScope-main/code/saved_models/cnn_dataframe.csv
# /content/drive/MyDrive/DengueScope-main/code/saved_models/.ipynb_checkpoints/cnn_dataframe-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/LSTM_Model_16-11-2024-19-45-22.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/LSTM_Model_18-11-2024-19-02-11.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/LSTM_Model_18-11-2024-20-21-17.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/LSTM_Model_16-11-2024-19-34-15.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-opti2-11-11-2024-14-41-19.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_new_model_23-11-2024-22-07-05.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-optimized-11-11-2024-02-47-28.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/LSTM_Model_18-11-2024-20-39-11.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-11-11-2024-02-48-45.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TFT_model_lagged_18-03-2025-22-51-57.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TFT_new_model_search_26-11-2024-10-47-11.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-10-11-2024-17-52-24.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_final_model_15-11-2024-22-51-14.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-10-11-2024-18-42-21.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/svm-07-11-2024-01-44-24.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost-07-11-2024-01-07-29.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_new_model_18-11-2024-23-29-17.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-new-13-11-2024-01-25-51.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost_18-11-2024-20-40-27.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/baseline-07-11-2024-01-12-00.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-optimized-11-11-2024-02-53-09.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost_18-11-2024-18-38-07.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_new_model_26-11-2024-00-40-59.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-new-13-11-2024-01-44-52.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TFT_new_model_search_26-11-2024-09-47-20.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/LSTM_Model_search_lagged_18-03-2025-20-16-03.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost-07-11-2024-00-59-37.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost_lagged_19-03-2025-00-47-00.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_10-11-2024-18-18-40_citywise.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_model_search_lagged_18-03-2025-21-59-40.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-11-11-2024-02-50-01.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-opti2-11-11-2024-14-38-36.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_new_model_18-11-2024-22-58-55.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_model_search_lagged_18-03-2025-12-22-20.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-11-11-2024-00-40-03.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/LSTM_Model_search_26-11-2024-00-44-37.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/LSTM_Model_26-11-2024-00-46-12.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_new_model_search_26-11-2024-00-27-43.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-main-11-11-2024-14-45-47.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost-06-11-2024-19-40-45.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost-07-11-2024-10-09-08.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost-07-11-2024-01-04-37.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/ensemble_results_07-05-2025-15-39-09.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/ensemble_results_01-05-2025-16-29-44.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-11-11-2024-00-38-02.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-10-11-2024-17-53-06.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TFT_model_search_18-03-2025-22-58-39.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/svm-07-11-2024-10-11-03.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/baseline-07-11-2024-10-10-28.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/ensemble_results_01-05-2025-20-19-39.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-new-13-11-2024-01-26-42.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-11-11-2024-02-39-37.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_new_model_18-11-2024-23-56-50.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost_search_26-11-2024-02-20-15.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_new_model_search_25-11-2024-23-18-38.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN_new_model_23-11-2024-22-05-26.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TFT_new_model_18-03-2025-23-03-37.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/catboost_normal26-11-2024-01-03-19.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-11-11-2024-00-54-04.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/TCN-11-11-2024-00-52-45.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/LSTM_Model_16-11-2024-19-45-22-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_new_model_18-11-2024-22-58-55-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/LSTM_Model_search_26-11-2024-00-44-37-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_new_model_18-11-2024-23-56-50-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_new_model_23-11-2024-22-05-26-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_new_model_search_26-11-2024-00-27-43-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_new_model_18-11-2024-23-29-17-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_model_search_lagged_18-03-2025-12-22-20-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_final_model_15-11-2024-22-51-14-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/svm-07-11-2024-10-11-03-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/LSTM_Model_18-11-2024-20-21-17-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-11-11-2024-02-39-37-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-opti2-11-11-2024-14-41-19-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-11-11-2024-00-54-04-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-10-11-2024-17-52-24-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-11-11-2024-00-38-02-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/catboost_18-11-2024-20-40-27-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-main-11-11-2024-14-45-47-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_new_model_search_25-11-2024-23-18-38-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/catboost-07-11-2024-10-09-08-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TFT_new_model_search_26-11-2024-09-47-20-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_10-11-2024-18-18-40_citywise-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/LSTM_Model_26-11-2024-00-46-12-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/LSTM_Model_18-11-2024-20-39-11-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-11-11-2024-00-40-03-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/catboost_18-11-2024-18-38-07-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-new-13-11-2024-01-44-52-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/catboost-07-11-2024-01-04-37-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-new-13-11-2024-01-25-51-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-optimized-11-11-2024-02-53-09-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/LSTM_Model_18-11-2024-19-02-11-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-11-11-2024-02-48-45-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-optimized-11-11-2024-02-47-28-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/baseline-07-11-2024-01-12-00-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_new_model_23-11-2024-22-07-05-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-11-11-2024-00-52-45-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/catboost_search_26-11-2024-02-20-15-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-10-11-2024-17-53-06-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-11-11-2024-02-50-01-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/catboost-06-11-2024-19-40-45-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-new-13-11-2024-01-26-42-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN-10-11-2024-18-42-21-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/svm-07-11-2024-01-44-24-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/TCN_new_model_26-11-2024-00-40-59-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/catboost_normal26-11-2024-01-03-19-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/catboost-07-11-2024-01-07-29-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/metrics/Brazil/.ipynb_checkpoints/LSTM_Model_16-11-2024-19-34-15-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/.ipynb_checkpoints/incremental_trends_data-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/.ipynb_checkpoints/model_predictions_metrics-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/.ipynb_checkpoints/reduced-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/.ipynb_checkpoints/out-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/.ipynb_checkpoints/reduced_2004_2019-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/.ipynb_checkpoints/reduced_for_tcn-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/code/dataset/Brazil_UF_dengue_monthly.csv
# /content/drive/MyDrive/DengueScope-main/code/dataset/.ipynb_checkpoints/Brazil_UF_dengue_monthly-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RJ_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PI_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MS_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AP_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RN_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RN_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RS_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PB_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/ES_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PI_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/ES_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AC_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SE_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/BA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AM_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AL_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RN_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RJ_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AL_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MT_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AC_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PE_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AM_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/GO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MA_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AC_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MT_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MT_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SP_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/BA_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AC_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PA_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MG_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SC_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AL_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/CE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/DF_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SC_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MA_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PI_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/CE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PI_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RN_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RJ_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SP_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AM_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SP_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/BA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AL_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SC_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PA_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RS_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/GO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/CE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RS_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RN_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MT_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/GO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AM_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RJ_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PB_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/GO_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MS_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MG_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PB_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RO_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MS_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AP_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RR_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/ES_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RR_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/DF_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PI_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/DF_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RS_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PR_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AL_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MG_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/CE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PR_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/CE_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AC_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/BA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/GO_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SC_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AP_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/BA_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/DF_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PB_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MG_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RJ_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MG_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/DF_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PB_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/ES_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/RS_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SC_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MS_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AP_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/ES_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/AM_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MS_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/MT_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PR_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/PR_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/TO_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/SP_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/TO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/TO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/TO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/TO_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/AP_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/AC_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/AM_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/CE_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/TO_sintomas_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/SE_mosquito_da_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/TO_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/AM_sintomas_de_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/AC_sintomas_de_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/DF_sintomas_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/PA_sintomas_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/AM_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_converted/.ipynb_checkpoints/AL_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MT_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MG_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/DF_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AL_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AP_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/BA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AC_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/BA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AM_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AL_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MS_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MS_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/CE_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AC_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/GO_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AM_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/DF_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/GO_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MS_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MT_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/BA_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/ES_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AM_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MS_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/CE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/DF_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/CE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AL_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AP_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MG_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AL_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MA_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/DF_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/BA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AL_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MG_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/ES_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/BA_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/ES_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AP_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MA_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AC_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/GO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AM_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/DF_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/ES_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AM_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/GO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AP_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MG_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/ES_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MS_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AC_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/AC_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/CE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/GO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MG_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/CE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RJ_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/TO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PI_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RJ_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/TO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PI_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PR_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MT_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RJ_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PB_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PI_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RS_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RS_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MT_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RR_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SC_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PA_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SC_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PA_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PR_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PB_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RO_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/TO_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PI_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RN_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SP_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RS_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PI_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SP_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SC_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SE_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RN_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SP_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PB_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SC_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/TO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/MT_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PR_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RN_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RR_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RS_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RN_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/TO_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PB_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RJ_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SP_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RS_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/SC_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RJ_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PR_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PE_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PB_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/RN_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/PE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/.ipynb_checkpoints/AC_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/serpapi_results_cleaned/.ipynb_checkpoints/TO_sintomas_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/BA_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/MS_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/RJ_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/ES_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/MG_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/SE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/PR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/PE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/SE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/AP_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/SP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/PB_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/BA_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/AP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/SC_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/AP_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/RN_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/SP_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/AC_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/PR_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/AM_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/GO_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/AL_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/AL_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/MA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/AL_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/ES_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/MS_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/RR_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/MG_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/TO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/PI_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/PI_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/PE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/filtered_results/MS_mosquito.csv
# ...
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/multiTimeline (219).csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/multiTimeline (220).csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RJ_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/CE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RS_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PB_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PA_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PA_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/CE_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/TO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SP_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MG_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MS_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/GO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SE_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RJ_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PR_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SE_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/ES_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RO_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SC_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SC_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RJ_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/DF_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MT_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SC_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MG_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PI_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MT_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RJ_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RS_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SC_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SC_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/GO_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PB_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SE_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RN_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/TO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MA_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/CE_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MA_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RJ_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/multiTimeline (221).csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RO_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MT_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PB_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RR_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RS_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/CE_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SE_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/TO_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RN_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PI_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RO_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/multiTimeline (218).csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/TO_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RJ_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PR_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PI_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/ES_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RO_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/DF_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PB_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MT_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/CE_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PR_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MA_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SP_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/ES_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/CE_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SP_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PR_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RN_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PR_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PI_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PR_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RO_sintomas_de_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/DF_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/TO_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SC_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RO_sintomas_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PA_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PI_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PI_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/GO_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/PA_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/ES_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/TO_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MT_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/SP_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/MT_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/RJ_mosquito_da_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/.ipynb_checkpoints/MA_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/.ipynb_checkpoints/AC_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/.ipynb_checkpoints/AC_sintomas_de_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/.ipynb_checkpoints/AC_repelente_contra_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/.ipynb_checkpoints/AL_sintomas_dengue-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/.ipynb_checkpoints/AC_febre_do_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/google trends/.ipynb_checkpoints/AL_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/serpapi_results_new/CE_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/serpapi_results_new/.ipynb_checkpoints/CE_mosquito-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_dataset_set2-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_dataset_lagged-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_dataset-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_dataset_set1-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/.ipynb_checkpoints/merged_test1-checkpoint.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PR_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/DF_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PI_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/SE_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/RN_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/SP_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PA_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/CE_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/MG_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/RS_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/RS_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/DF_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/MG_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/SP_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/SC_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/AP_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/MA_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/TO_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/RS_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/MS_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PB_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/ES_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/ES_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/CE_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/AM_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PE_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/SP_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/GO_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PB_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/GO_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/AL_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/RJ_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/BA_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PE_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PI_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/AC_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PR_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/BA_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PA_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/TO_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/AM_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/PR_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/BA_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/ES_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/AP_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/DF_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/CE_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/MG_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/SC_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/RJ_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/SC_tratamento_para_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/RJ_repelente_contra_dengue.csv
# /content/drive/MyDrive/DengueScope-main/google trends/excluded_terms/MT_febre_do_mosquito.csv
# /content/drive/MyDrive/DengueScope-main/predictions/catboost_predictions.csv
# /content/drive/MyDrive/DengueScope-main/predictions/ensemble_predictions.csv
# /content/drive/MyDrive/DengueScope-main/predictions/ensemble_predictions_fixed.csv
# /content/drive/MyDrive/DengueScope-main/predictions/ensemble_valid.csv
